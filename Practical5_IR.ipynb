# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwinibarapatre28/Information_Retrieval/blob/main/Practical5_IR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ashwini Khushal Barapatre**
#
# **CS23118**

# %%
import math
import string

# %%
doc1 = "Information retrieval is fun and interesting"
doc2 = "Information processing and retrieval systems"
doc3 = "Retrieval of information from systems is important"
documents = [doc1, doc2, doc3]

# %%
stopwords = {"is", "and", "of", "from", "the", "a", "an"}

# %%
processed_docs = []
for doc in documents:
    doc = doc.lower()  # convert to lowercase
    doc = doc.translate(str.maketrans("", "", string.punctuation))  # remove punctuation
    words = doc.split()  # tokenization
    words = [word for word in words if word not in stopwords]  # remove stopwords
    processed_docs.append(words)

# %%
vocab = sorted(set(word for doc in processed_docs for word in doc))

print("Vocabulary (Alphabetical Order):")
print(vocab)
# Out:
# Vocabulary (Alphabetical Order):
# ['fun', 'important', 'information', 'interesting', 'processing', 'retrieval', 'systems']

# %%
vectors = []
for doc in processed_docs:
    vector = []
    for word in vocab:
        if word in doc:
            vector.append(1)
        else:
            vector.append(0)
    vectors.append(vector)

# Print Document Vectors
for i in range(len(vectors)):
    print(f"\nDocument {i+1} Vector:")
    print(vectors[i])
# Out:
# Document 1 Vector:
# [1, 0, 1, 1, 0, 1, 0]
#
# Document 2 Vector:
# [0, 0, 1, 0, 1, 1, 1]
#
# Document 3 Vector:
# [0, 1, 1, 0, 0, 1, 1]

# %%
def cosine_similarity(v1, v2):
    dot_product = sum(a*b for a, b in zip(v1, v2))
    magnitude1 = math.sqrt(sum(a*a for a in v1))
    magnitude2 = math.sqrt(sum(b*b for b in v2))

    if magnitude1 == 0 or magnitude2 == 0:
        return 0

    return dot_product / (magnitude1 * magnitude2)

# %%
print("\nCosine Similarities:")
print("D1 & D2:", cosine_similarity(vectors[0], vectors[1]))
print("D1 & D3:", cosine_similarity(vectors[0], vectors[2]))
print("D2 & D3:", cosine_similarity(vectors[1], vectors[2]))
# Out:
# Cosine Similarities:
# D1 & D2: 0.5
# D1 & D3: 0.5
# D2 & D3: 0.75
